# %%
# !cd Wav2Lip && python inference.py --checkpoint_path "checkpoints/Wav2Lip-SD-GAN.pt" --face "../sample_data/img_1.jpg" --audio "../sample_data/sound.mp3"
# Out:
# Using cpu for inference.
# Reading video frames...
# Number of frames available for inference: 1
# Extracting raw audio...
# (80, 2354)
# Length of mel chunks: 732
# Load checkpoint from: checkpoints/Wav2Lip-SD-GAN.pt
# Model loaded
# ffmpeg version 7.1.1-essentials_build-www.gyan.dev Copyright (c) 2000-2025 the FFmpeg developers
#   built with gcc 14.2.0 (Rev1, Built by MSYS2 project)
# ...
